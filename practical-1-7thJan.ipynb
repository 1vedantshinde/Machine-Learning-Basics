# %%
#Date: 07-01-2025
#SML - Practical 1: Linear Regression (if plot size is given predict the housing price)

#Libraries
import matplotlib.pyplot as plt #
import numpy as np #
import pandas as pd #
from sklearn import linear_model #
from sklearn.model_selection import train_test_split #
from sklearn.metrics import r2_score

# %%
#Load and Prepare Dataset 
df = pd.read_csv('D:/Users/Downloads/Housing.csv')

# %%
df.head() #
# Out:
#    rownames  price  lotsize  bedrooms  ...  gashw  airco garagepl prefarea
# 0         1  42000     5850         3  ...     no     no        1       no
# 1         2  38500     4000         2  ...     no     no        0       no
# 2         3  49500     3060         3  ...     no     no        0       no
# 3         4  60500     6650         3  ...     no     no        0       no
# 4         5  61000     6360         2  ...     no     no        0       no
#
# [5 rows x 13 columns]

# %%
#Outputs top 5 records by default but can be changed 
df.tail()
# Out:
#      rownames   price  lotsize  bedrooms  ...  gashw  airco garagepl prefarea
# 541       542   91500     4800         3  ...     no    yes        0       no
# 542       543   94000     6000         3  ...     no    yes        0       no
# 543       544  103000     6000         3  ...     no    yes        1       no
# 544       545  105000     6000         3  ...     no    yes        1       no
# 545       546  105000     6000         3  ...     no    yes        1       no
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  546 non-null    int64
#  1   price     546 non-null    int64
#  2   lotsize   546 non-null    int64
#  3   bedrooms  546 non-null    int64
#  4   bathrms   546 non-null    int64
#  5   stories   546 non-null    int64
#  6   driveway  546 non-null    object
#  7   recroom   546 non-null    object
#  8   fullbase  546 non-null    object
#  9   gashw     546 non-null    object
#  10  airco     546 non-null    object
#  11  garagepl  546 non-null    int64
#  12  prefarea  546 non-null    object
# dtypes: int64(7), object(6)
# memory usage: 55.6+ KB

# %%
df.describe()
# Out:
#          rownames          price  ...     stories    garagepl
# count  546.000000     546.000000  ...  546.000000  546.000000
# mean   273.500000   68121.597070  ...    1.807692    0.692308
# std    157.760895   26702.670926  ...    0.868203    0.861307
# min      1.000000   25000.000000  ...    1.000000    0.000000
# 25%    137.250000   49125.000000  ...    1.000000    0.000000
# 50%    273.500000   62000.000000  ...    2.000000    0.000000
# 75%    409.750000   82000.000000  ...    2.000000    1.000000
# max    546.000000  190000.000000  ...    4.000000    3.000000
#
# [8 rows x 7 columns]

# %%
df.shape
# Out:
# (546, 13)

# %%
x = df['lotsize'] #Single predictor / independent variable
y = df['price'] #Target/Dependent variable

# %%
#RESHAPE THE DATA (objects -> 1d -> 2d)
x = x.values.reshape(len(x), 1)
y = y.values.reshape(len(y), 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
reg = linear_model.LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color='green')

# %%
plt.scatter(x_test, y_test, color='red')

# %%
plt.scatter(x, y, color='black')

# %%
plt.scatter(x_train, y_train, color='green')
plt.scatter(x_test, y_test, color='red')

# %%
y_predict = reg.predict(x_test)

# %%
plt.plot(x_test, y_predict, color='gold')

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_predict, color='gold')

# %%
plt.scatter(x, y, color='blue')
plt.plot(x_test, y_predict, color='gold')

# %%
#Given: x = 175, Predict Y
#Eqn: y = 0.1x + 50
#Therefore Y = 67.5
#m is the coefficient parameter in terms of programming even though c is a coefficient as well
#c is the intercept
print(reg.coef_)
print(reg.intercept_)
#y = mx + c
# Out:
# [[6.53280798]]
# [35153.74208044]

# %%
print(f'y = {reg.coef_}x + {reg.intercept_}')
# Out:
# y = [[6.53280798]]x + [35153.74208044]

# %% [markdown]
# Demonstrate multiple linear regression predict price but the input should be minimum three

# %%
x1 = [df['lotsize'], df['bedrooms'], df['bathrms']]
y = df['price']

# %%
x = x.values.reshape(len(x), 1)
y = y.values.reshape(len(y), 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 x = x.values.reshape(len(x), 1)
#       2 y = y.values.reshape(len(y), 1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
